# %%
from langsmith import Client, evaluate

# Import your wrapper function from your main workflow file
from main_v6 import run_text2sql

# %%
# Local Testing

user_query = "Show the top 3 products within each category by sales"

result = run_text2sql(user_query)

print(result["answer"])
# Out:
# WITH ranked_products AS (SELECT op.product_id, op.product_category_name, SUM(oi.price) AS total_sales, ROW_NUMBER() OVER(PARTITION BY op.product_category_name ORDER BY SUM(oi.price) DESC) AS rank FROM olist_products_dataset op LEFT JOIN olist_order_items_dataset oi ON op.product_id = oi.product_id GROUP BY op.product_id, op.product_category_name) SELECT product_id, product_category_name, total_sales FROM ranked_products WHERE rank <= 3 ORDER BY product_category_name, rank;

# %%
# LangSmith Evaluation

client = Client()

dataset_name = "text2sql"       # dataset name in LangSmith

evaluate(
    run_text2sql,
    #data=dataset_name,
    data=client.list_examples(dataset_name=dataset_name, splits=["base"]), # quick_test, golden_set, base
    experiment_prefix="text2sql-v6-eval",
    num_repetitions=2, # This field defaults to 1
    max_concurrency=2 # This defaults to None
)
# Out:
# View the evaluation results for experiment: 'text2sql-v6-eval-0eb165b0' at:
# https://smith.langchain.com/o/ab7cd12a-fb8c-4c9e-89ca-973973263c4f/datasets/20ff443e-0445-4ed2-a041-aeb943e6b317/compare?selectedSessions=a039bbe4-023c-4252-8bc0-96bbaff8456a
# 1it [00:05,  5.62s/it]
